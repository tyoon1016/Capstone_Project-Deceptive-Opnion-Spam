# %%
import pandas as pd
from pandas import DataFrame

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests

# %%
# Amalfi Hotel changed to Kinzie

amalfi1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-Kinzie_Hotel-Chicago_Illinois.html'
amalfi2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or5-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or10-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or15-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or20-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or25-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or30-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or35-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or30-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or45-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or50-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or45-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or60-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or65-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or70-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'
amalfi16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d293203-Reviews-or75-Kinzie_Hotel-Chicago_Illinois.html#REVIEWS'

amalfi = [amalfi1, amalfi2, amalfi3, amalfi4, amalfi5, amalfi6, amalfi7, amalfi8, amalfi9, amalfi10, 
          amalfi11, amalfi12, amalfi13, amalfi14, amalfi15, amalfi16]

# %%
# Affinia changed name to Hotel One Sisxty Six Magnificient Mile

affinia1 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html'
affinia2 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or5-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia3 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or10-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia4 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or15-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia5 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or20-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia6 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or25-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia7 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or30-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia8 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or35-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia9 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or40-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia10 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or45-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia11 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or50-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia12 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or55-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia13 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or60-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia14 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or65-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia15 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or70-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
affinia16 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d114595-Reviews-or75-Hotel_One_Sixty_Six_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'

affinia = [affinia1, affinia2, affinia3, affinia4, affinia5, affinia6, affinia7, affinia8, affinia9, affinia10,
             affinia11, affinia12, affinia13, affinia14, affinia15, affinia16]

# %%
# Allegro hotel is Kimpton Hotel Chicago

allegro1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-Kimpton_Hotel_Allegro-Chicago_Illinois.html'
allegro2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or5-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or10-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or15-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or20-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or25-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or30-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or35-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or40-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro10 =f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or45-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or50-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or55-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or60-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or65-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or70-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'
allegro16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90985-Reviews-or75-Kimpton_Hotel_Allegro-Chicago_Illinois.html#REVIEWS'

allegro = [allegro1, allegro2, allegro3, allegro4, allegro5, allegro6, allegro7, allegro8, allegro9, allegro10,
           allegro11, allegro12, allegro13, allegro14, allegro15, allegro16,]

# %%
# Ambassador hotel

ambassador1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-Ambassador_Chicago-Chicago_Illinois.html'
ambassador2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or5-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or10-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or15-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or20-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or25-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or30-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or35-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or40-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or45-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or50-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or55-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or60-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or65-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or70-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'
ambassador16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87629-Reviews-or75-Ambassador_Chicago-Chicago_Illinois.html#REVIEWS'

ambassador = [ambassador1, ambassador2, ambassador3, ambassador4, ambassador5, ambassador6, ambassador7, ambassador8, 
              ambassador9, ambassador10, ambassador11, ambassador12, ambassador13, ambassador14, ambassador15, ambassador16,]

# %%
# Conrad

conrad1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-Conrad_Chicago-Chicago_Illinois.html'
conrad2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or5-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or10-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or15-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or20-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or25-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or30-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or35-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or40-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or45-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or50-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or55-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or60-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or65-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or70-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'
conrad16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d10211870-Reviews-or75-Conrad_Chicago-Chicago_Illinois.html#REVIEWS'

conrad = [conrad1, conrad2, conrad3, conrad4, conrad5, conrad6, conrad7, conrad8, conrad9, conrad10,
          conrad11, conrad12, conrad13, conrad14, conrad15, conrad16]

# %%
# Fairmont

fairmont1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html'
fairmont2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or5-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or10-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or15-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or20-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or25-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or30-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or35-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or40-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or45-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or50-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or55-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or60-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or65-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or70-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'
fairmont16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114577-Reviews-or75-Fairmont_Chicago_Millennium_Park-Chicago_Illinois.html#REVIEWS'

fairmont = [fairmont1, fairmont2, fairmont3, fairmont4, fairmont5, fairmont6, fairmont7, fairmont8, fairmont9, fairmont10,
            fairmont11, fairmont12, fairmont13, fairmont14, fairmont15, fairmont16]

# %%
# Hilton

hilton1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-Hilton_Chicago-Chicago_Illinois.html'
hilton2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or5-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or10-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or15-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or20-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or25-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or30-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or35-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or40-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or45-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or50-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or55-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or60-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or65-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or70-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'
hilton16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87590-Reviews-or75-Hilton_Chicago-Chicago_Illinois.html#REVIEWS'

hilton = [hilton1, hilton2, hilton3, hilton4, hilton5, hilton6, hilton7, hilton8, hilton9, hilton10,
          hilton11, hilton12, hilton13, hilton14, hilton15, hilton16]

# %%
# Homewood

homewood1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html'
homewood2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or5-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or10-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or15-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or20-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or25-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or30-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or35-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or40-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or45-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or50-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or55-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or60-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or65-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or70-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'
homewood16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90959-Reviews-or75-Homewood_Suites_by_Hilton_Chicago_Downtown-Chicago_Illinois.html#REVIEWS'


homewood = [homewood1, homewood2, homewood3, homewood4, homewood5, homewood6, homewood7, homewood8, homewood9, homewood10,
            homewood11, homewood12, homewood13, homewood14, homewood15, homewood6]

# %%
hyatt1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html'
hyatt2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or5-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or10-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or15-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or20-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or25-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or30-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or35-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or40-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or45-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or50-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or55-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or60-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or65-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or70-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
hyatt16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90952-Reviews-or75-Hyatt_Centric_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'

hyatt = [hyatt1, hyatt2, hyatt3, hyatt4, hyatt5, hyatt6, hyatt7, hyatt8, hyatt9, hyatt10,
         hyatt11, hyatt12, hyatt13, hyatt14, hyatt15, hyatt16]

# %%
# Intercontinental

inter1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html'
inter2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or5-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or10-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or15-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or20-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or25-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or30-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or35-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or40-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or45-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or50-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or55-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or60-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or65-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or70-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
inter16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87620-Reviews-or75-InterContinental_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'

inter = [inter1, inter2, inter3, inter4, inter5, inter6 , inter7, inter8, inter9, inter10,
         inter11, inter12, inter13, inter14, inter15, inter16]

# %%
# FourSeasons

four1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html'
four2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or5-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or10-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or15-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or20-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or25-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or30-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or35-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or40-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or45-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or50-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or55-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or60-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or65-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or70-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'
four16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114591-Reviews-or75-Four_Seasons_Hotel_Chicago-Chicago_Illinois.html#REVIEWS'

four = [four1, four2, four3, four4, four5, four6, four7, four8, four9, four10,
        four11, four12, four13, four14, four15, four16]

# %%
# Hotel Chicago Autograph

chic1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html'
chic2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or5-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or10-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or15-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or20-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or25-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or30-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or35-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or40-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or45-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or50-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or55-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or60-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or65-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or70-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'
chic16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d90957-Reviews-or75-Hotel_Chicago_Downtown_Autograph_Collection-Chicago_Illinois.html#REVIEWS'

chic = [chic1, chic2, chic3, chic4, chic5, chic6, chic7, chic8, chic9, chic10,
        chic11, chic12, chic13, chic14, chic15, chic16]

# %%
# Millennium Knickerbocker Chicago

Mill1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html'
mill2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or5-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or10illennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or1-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or20-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or25-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or30-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or35-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or40-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill10 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or45-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
Mill11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or50-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or55-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or60illennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or65-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or70-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'
mill16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87648-Reviews-or75-Millennium_Knickerbocker_Chicago-Chicago_Illinois.html#REVIEWS'

mill = [Mill1 , mill2, mill3, mill4, mill5, mill6, mill7, mill8, mill9, mill10,
        Mill11 , mill12, mill13, mill14, mill15, mill16]

# %%
# Kimpton Monaco 

monaco1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html'
monaco2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or5-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or10-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or15-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or20-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or25-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or30-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or35-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or40-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or45-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or50-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or55-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or60-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or65-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or70-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'
monaco16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111492-Reviews-or75-Kimpton_Hotel_Monaco_Chicago-Chicago_Illinois.html#REVIEWS'

monaco = [monaco1, monaco2, monaco3, monaco4, monaco5, monaco6, monaco7, monaco8, monaco9, monaco10,
          monaco11, monaco12, monaco13, monaco14, monaco15, monaco16]

# %%
# Omni Chicago

omni1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-Omni_Chicago_Hotel-Chicago_Illinois.html'
omni2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or5-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or10-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or15-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or20-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or25-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or30-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or35-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or40-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or45-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or50-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or55-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or60-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or65-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or70-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'
omni16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111500-Reviews-or75-Omni_Chicago_Hotel-Chicago_Illinois.html#REVIEWS'

omni = [omni1, omni2, omni3, omni4, omni5, omni6, omni7, omni8, omni9, omni10,
        omni11, omni12, omni13, omni14, omni15, omni16]

# %%
# Palmer House Hilton

palmer1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html'
palmer2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or5-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or10-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or15-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or20-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or25-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or30-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or35-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or40-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or45-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or50-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or55-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or60-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or65-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or70-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'
palmer16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d111501-Reviews-or75-Palmer_House_A_Hilton_Hotel-Chicago_Illinois.html#REVIEWS'

palmer = [palmer1, palmer2, palmer3, palmer4, palmer5, palmer6, palmer7, palmer8, palmer9, palmer10,
          palmer11, palmer12, palmer13, palmer14, palmer15, palmer16]

# %%
# Sheraton

shera1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-Sheraton_Grand_Chicago-Chicago_Illinois.html'
shera2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or5-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or10-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or15-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or20-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or25-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or30-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or35-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or40-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or45-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or50-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or55-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or60-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or65-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or70-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'
shera16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87638-Reviews-or75-Sheraton_Grand_Chicago-Chicago_Illinois.html#REVIEWS'


shera = [shera1, shera2, shera3, shera4, shera5, shera6, shera7, shera8, shera9, shera10,
         shera11, shera12, shera13, shera14, shera15, shera16]

# %%
# Sofitel Chicago

sofitel1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or5-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or10-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or15-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or20-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or25-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or30-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or35-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or40-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or45-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or50-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or55-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or60-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or65-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or70-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'
sofitel16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d236299-Reviews-or75-Sofitel_Chicago_Magnificent_Mile-Chicago_Illinois.html#REVIEWS'


sofitel = [sofitel1, sofitel2, sofitel3, sofitel4, sofitel5, sofitel6, sofitel7, sofitel8, sofitel9, sofitel10,
           sofitel11, sofitel12, sofitel13, sofitel14, sofitel15, sofitel16]

# %%
# Swissotel

swisso1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-Swissotel_Chicago-Chicago_Illinois.html'
swisso2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or5-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or10-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or15-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or20-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or25-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or30-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or35-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or40-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or45-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or50-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or55-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or60-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or65-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or70-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'
swisso16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d114581-Reviews-or75-Swissotel_Chicago-Chicago_Illinois.html#REVIEWS'

swisso = [swisso1, swisso2, swisso3, swisso4, swisso5, swisso6, swisso7, swisso8, swisso9, swisso10,
          swisso11, swisso12, swisso13, swisso14, swisso15, swisso16]

# %%
# Talbott Hotel

talbott1 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-The_Talbott_Hotel-Chicago_Illinois.html'
talbott2 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or5-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott3 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or10-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott4 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or15-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott5 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or20-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott6 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or25-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott7 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or30-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott8 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or35-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott9 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or40-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott10= f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or45-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott11 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or50-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott12 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or55-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott13 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or60-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott14 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or65-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott15 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or70-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'
talbott16 = f'https://www.tripadvisor.com/Hotel_Review-g35805-d87654-Reviews-or75-The_Talbott_Hotel-Chicago_Illinois.html#REVIEWS'

talbott = [talbott1, talbott2, talbott3, talbott4, talbott5, talbott6, talbott7, talbott8, talbott9, talbott10,
           talbott11, talbott12, talbott13, talbott14, talbott15, talbott16]

# %%
group1 = [amalfi, affinia,allegro,ambassador]
group2 = [conrad, fairmont, hilton, homewood]
group3 = [hyatt, inter, four, chic]
group4 = [mill, monaco, omni, palmer]
group5 = [shera, sofitel,swisso, talbott]

hotels = [amalfi, affinia,allegro,ambassador,
          conrad, fairmont, hilton, homewood,
          hyatt, inter, four, chic,
          mill, monaco, omni, palmer,
          shera, sofitel,swisso, talbott]

# %%
# Web scraping function using beautiful soup 
# Uses for-loop to get all 1600 reviews from each tripadvisor webapge

def extract(page):
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
    for i in hotels:
        for j in i:
            r = requests.get(j, headers)
            soup = BeautifulSoup(r.content, 'html.parser')
            divs = soup.find_all('div', class_="_2f_ruteS _1bona3Pu _2uD5bLZZ")
            for item in divs:
                review = item.find('span').text
                reviews.append(review)
    return

        
reviews= []
extract(0)

# %%
# Checking numbers
len(reviews)
# Out:
# 1600

# %%
reviews
# Out:
# ['We had a great stay! The location was convenient to everything! We found a great place for breakfast nearby (Yolk). The corner king room had a great view. Staff was excellent- Michelle was great and so helpful. When we come back, we will stay here again.',
#  'My parents came to this hotel in August because I was having a family reunion at home and it was too small to accommodate them, I would like to thank the staff for their kindness and for having met the expectations of my parents, they loved their stay with you, beautiful room with all the comfort they needed, excellent breakfast, thank you',
# ...

# %%
# To data frame
df_reviews = DataFrame(reviews, columns = ['reviews'])
df_reviews
# Out:
#                                       unlabeled_reviews
# 0     We had a great stay! The location was convenie...
# 1     My parents came to this hotel in August becaus...
# 2     The staff was amazing and offered such great a...
# 3     We stayed at the kinzie this past weekend and ...
# 4     The staff was very welcoming from walking thro...
# ...                                                 ...
# 1595  Very Hotel. Not thrilled with the remodeling o...
# 1596  I used to live in Chicago, so love that when I...
# 1597  We stayed for a few days over the Holidays.  I...
# 1598  The Talbott Hotel is the place to stay while v...
# 1599  My partner and I were looking forward to visit...
#
# [1600 rows x 1 columns]

# %%
# Saving as CSV file
df_reviews.to_csv(r'C:\Users\Jun\Data_Sci\Capstone\unlabeled_reviews.csv')
